# %% [markdown]
# ### web mining,
#  you need your Python code to act like a browser, sending requests to servers and receiving HTML responses.
#
# ### Send the GET Request
# response = requests.get(URL)
# ### Print the HTML content of the page
# print(response.text)
#
# +========================================================

# %%
import sys
print(sys.executable)
# Out:
# /home/susan/tripleten review/software_development_tools/.venv/bin/python

# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# What is the requests library?
#Visit websites
# Download web pages
# Send data to servers
# Interact with web APIs
import requests
# Step 2: Define the URL
URL = 'https://books.toscrape.com/'
# Step 3: Send the GET Request
response = requests.get(URL)
# Print the HTML content of the page
#print(response.text)

print()
print('='* 40)
print(response.url)
# Out:
# ...
# https://books.toscrape.com/

# %% [markdown]
# Now it's time to write your first GET request!
#
# Send a GET request to https://books.toscrape.com/ and print the status code of the response.
#
# Follow these steps:
#
# Define a variable URL containing the website address
# Use requests.get() to send a GET request and save the response in a variable called response
# Print the status code using response.status_code
# If everything works correctly, you should see 200 printed, which means success!

# %%
URL = 'https://books.toscrape.com/'
response = requests.get(URL)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# Task : 2.
#
# Great! Now that you've successfully sent a GET request, let's examine what the server sent back.
#
# The response object has a text attribute that contains the actual HTML content of the webpage. Print the first 1000 characters of the HTML content to see what you received from the server.

# %%
print(response.text[:1000])
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->
#     <head>
#         <title>
#     All products | Books to Scrape - Sandbox
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#         <meta name="created" content="24th Jun 2016 09:29" />
#         <meta name="description" content="" />
#         <meta name="viewport" content="width=device-width" />
#         <meta name="robots" content="NOARCHIVE,NOCACHE" />
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#         <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#
#
# ...

# %% [markdown]
# ### Task3.
#
# Now let's add some error handling! Not all requests succeed — sometimes pages don't exist, servers are down, or there are other issues.
#
# Write an if/else statement that:
#
# Checks if the status_code equals 200
# If it's 200, print: "Success! Page fetched successfully."
# Otherwise, print: "Error: Received status code {response.status_code}" (use an f-string to include the actual status code)

# %%
URL = 'https://books.toscrape.com/'
response = requests.get(URL)
# if/else statement
if response.status_code ==200:
    print("Success! Page fetched successfully.")
else:
    print(f"Error: Received status code {response.status_code}")
# Out:
# Success! Page fetched successfully.

# %% [markdown]
# ### Task 4
# Now let's see the real power of automation! Instead of fetching one page at a time, you can fetch multiple pages automatically using a loop.
#
# You're given a list of URLs for the first 5 pages of books. Write a for loop that:
#
# Iterates through each URL in the pages list
# Sends a GET request to each page
# Checks if the status code is 200
# If successful, prints: "Successfully fetched {page}" (use an f-string to include the page URL)

# %%
pages = [
    'https://books.toscrape.com/catalogue/page-1.html',
    'https://books.toscrape.com/catalogue/page-2.html',
    'https://books.toscrape.com/catalogue/page-3.html',
    'https://books.toscrape.com/catalogue/page-4.html',
    'https://books.toscrape.com/catalogue/page-5.html',
]

# Step 3: Send the GET Request
response = requests.get(URL)
# Print the HTML content of the page
print(response.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->
#     <head>
#         <title>
#     All products | Books to Scrape - Sandbox
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#         <meta name="created" content="24th Jun 2016 09:29" />
#         <meta name="description" content="" />
#         <meta name="viewport" content="width=device-width" />
#         <meta name="robots" content="NOARCHIVE,NOCACHE" />
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#         <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#
#
# ...

# %%
for page in pages:
    requests.get(page)
    if response.status_code ==200:
      print(f"Successfully fetched {pages}")
# Out:
# Successfully fetched ['https://books.toscrape.com/catalogue/page-1.html', 'https://books.toscrape.com/catalogue/page-2.html', 'https://books.toscrape.com/catalogue/page-3.html', 'https://books.toscrape.com/catalogue/page-4.html', 'https://books.toscrape.com/catalogue/page-5.html']
# Successfully fetched ['https://books.toscrape.com/catalogue/page-1.html', 'https://books.toscrape.com/catalogue/page-2.html', 'https://books.toscrape.com/catalogue/page-3.html', 'https://books.toscrape.com/catalogue/page-4.html', 'https://books.toscrape.com/catalogue/page-5.html']
# Successfully fetched ['https://books.toscrape.com/catalogue/page-1.html', 'https://books.toscrape.com/catalogue/page-2.html', 'https://books.toscrape.com/catalogue/page-3.html', 'https://books.toscrape.com/catalogue/page-4.html', 'https://books.toscrape.com/catalogue/page-5.html']
# ...

# %% [markdown]
# ### Understanding API Documentation and Swagger UI
#
# *`Swagger UI is an open-source tool that generates interactive web documentation  allows you to explore and test an API directly from your browser without writing code.`*
# ### Using Parameters in Python
# How Parameters Work
#
# In a URL, parameters come after a ? and are formatted as key=value pairs:
#
# <https://api-v3.mbta.com/routes?filter[type]=0&include=stop>
#                                ↑
#                           Parameters start here

# %%
# API
BASE_URL = 'https://api-v3.mbta.com/routes'
# Define your parameters in a dictionary
params = {
    "filter[type]": "0",  # Filter for light rail routes only (type 0)
    "include": "stop"     # Include stop information in the response
}

# Pass the params to requests.get()
response = requests.get(BASE_URL, params=params)
print("Status Code:", response.status_code)
print(response.text[:1000])  # Print first 1000 characters
# Out:
# Status Code: 200
# ...

# %%
# Working with GET Requests and Parameters
BASE_URL = 'https://api-v3.mbta.com/routes'
PARAMS = {
    "filter[type]": "0,1"  # This filters for light rail and heavy rail routes
}

response = requests.get(url=BASE_URL, params=PARAMS)

print(response.text)
# Out:
# {"data":[{"attributes":{"color":"DA291C","description":"Rapid Transit","direction_destinations":["Ashmont/Braintree","Alewife"],"direction_names":["South","North"],"fare_class":"Rapid Transit","listed_route":true,"long_name":"Red Line","short_name":"","sort_order":10010,"text_color":"FFFFFF","type":1},"id":"Red","links":{"self":"/routes/Red"},"relationships":{"agency":{"data":{"id":"1","type":"agency"}},"line":{"data":{"id":"line-Red","type":"line"}}},"type":"route"},{"attributes":{"color":"DA291C","description":"Rapid Transit","direction_destinations":["Mattapan","Ashmont"],"direction_names":["Outbound","Inbound"],"fare_class":"Rapid Transit","listed_route":true,"long_name":"Mattapan Line","short_name":"","sort_order":10011,"text_color":"FFFFFF","type":0},"id":"Mattapan","links":{"self":"/routes/Mattapan"},"relationships":{"agency":{"data":{"id":"1","type":"agency"}},"line":{"data":{"id":"line-Mattapan","type":"line"}}},"type":"route"},{"attributes":{"color":"ED8B00","description":"
# ...

# %% [markdown]
# # Task1.
#
# Make your first request to the MBTA API to get information about all routes.
#
# Create a variable BASE_URL with the routes endpoint and send a GET request. Store the response in a variable called response, then print the status code to verify your request was successful.

# %%
BASE_URL = 'https://api-v3.mbta.com/routes'
response = requests.get(BASE_URL)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# # Task2.
#
# Now let's use parameters to filter the results! Get only light rail routes (type 0) from the MBTA API.
#
# Create a params dictionary with a filter[type] parameter set to "0" for light rail routes. Send the request with these parameters and print the status code.

# %%
# Create Parameters
params ={"filter[type]":"0"}# Get light rail routes only
response= requests.get(BASE_URL, params = params)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# #Task 3.
# Let's combine multiple parameters! Get bus routes (type 3) but limit the results to just 5 routes so you're not overwhelmed with data.
#
# Create a params dictionary with two parameters:
#
# filter[type] set to "3" for bus routes
# page[limit] set to "5" to limit results
# Print both the status code and the first 800 characters of the response text.

# %%
params ={"filter[type]":"3", "page[limt]":"5"}# Get light rail routes only
response= requests.get(BASE_URL, params = params)
# print status_code 
print(response.status_code)
# print the first 800 characters of the response text
print(response.text[:800])
# Out:
# 200
# {"data":[{"attributes":{"color":"7C878E","description":"Frequent Bus","direction_destinations":["Logan Airport Terminals","South Station"],"direction_names":["Outbound","Inbound"],"fare_class":"Rapid Transit","listed_route":true,"long_name":"Logan Airport Terminals - South Station","short_name":"SL1","sort_order":10051,"text_color":"FFFFFF","type":3},"id":"741","links":{"self":"/routes/741"},"relationships":{"agency":{"data":{"id":"1","type":"agency"}},"line":{"data":{"id":"line-SLWaterfront","type":"line"}}},"type":"route"},{"attributes":{"color":"7C878E","description":"Frequent Bus","direction_destinations":["Design Center","South Station"],"direction_names":["Outbound","Inbound"],"fare_class":"Rapid Transit","listed_route":true,"long_name":"Design Center - South Station","short_name":"S

# %% [markdown]
# ## Task4.
# .
#
# Now let's get additional related data using the include parameter! Get light rail routes (type 1) and include information about the stops along each route.
#
# Create a params dictionary with:
#
# filter[type] set to "1" for heavy rail
# include set to "stop" to include stop information
# page[limit] set to "2" to keep the data manageable
# Print the status code and the first 1000 characters of the response.

# %%
params ={"filter[type]":"1",# Bus routes
         "page[limt]":"2", # Limit to 5 results
         "include": "stop" # Include stop details
         } # 
response= requests.get(BASE_URL, params = params)
# print status_code 
print(response.status_code)
# print the first 800 characters of the response text
print(response.text[:1000])
# Out:
# 200
# ...

# %% [markdown]
# # REST API
# What is a REST API?
# REST stands for `REpresentational State Transfer. `
#
# **Breaking it down:**
#
# * REpresentational: Data is represented in a format (usually JSON)
# * State: The current condition of a resource (like a user account, a product, etc.)
# * Transfer: Moving that representation between client and server
# In simple terms: REST is a set of architectural principles for building web APIs. When an API follows these principles, we call it a "REST API" or "RESTful API."
#
# * GET: Read a list of all objects or one single object by ID.
# * POST: Add a new object by sending JSON data.
# * PUT / PATCH: Update an existing object.
# * DELETE: Remove an object by its ID

# %%
import requests

url = "https://api.restful-api.dev/objects"

response = requests.get(url)# Asks the website: “Please give me your data.”

data = response.json()# Converts the website’s answer into Python data.

print(data)
# Out:
# [{'id': '1', 'name': 'Google Pixel 6 Pro', 'data': {'color': 'Cloudy White', 'capacity': '128 GB'}}, {'id': '2', 'name': 'Apple iPhone 12 Mini, 256GB, Blue', 'data': None}, {'id': '3', 'name': 'Apple iPhone 12 Pro Max', 'data': {'color': 'Cloudy White', 'capacity GB': 512}}, {'id': '4', 'name': 'Apple iPhone 11, 64GB', 'data': {'price': 389.99, 'color': 'Purple'}}, {'id': '5', 'name': 'Samsung Galaxy Z Fold2', 'data': {'price': 689.99, 'color': 'Brown'}}, {'id': '6', 'name': 'Apple AirPods', 'data': {'generation': '3rd', 'price': 120}}, {'id': '7', 'name': 'Apple MacBook Pro 16', 'data': {'year': 2019, 'price': 1849.99, 'CPU model': 'Intel Core i9', 'Hard disk size': '1 TB'}}, {'id': '8', 'name': 'Apple Watch Series 8', 'data': {'Strap Colour': 'Elderberry', 'Case Size': '41mm'}}, {'id': '9', 'name': 'Beats Studio3 Wireless', 'data': {'Color': 'Red', 'Description': 'High-performance wireless noise cancelling headphones'}}, {'id': '10', 'name': 'Apple iPad Mini 5th Gen', 'data': {'Cap
# ...

# %%
#GET means: Give me data.
# POST means: I am sending new data to you.
# This is the new information we want to send.
new_item = {
    "name": "My phone",
    "data": {
        "color": "black",
        "price": 500
    }
}
# url → where we send the information
# json=new_item → the information we send
response = requests.post(url, json=new_item)

created_item = response.json()

print(created_item)
# The API creates the id automatically.
# Out:
# {'id': 'ff8081819f7e10ae019fa478aaad34be', 'name': 'My phone', 'createdAt': 1785170799277, 'data': {'color': 'black', 'price': 500}}

# %%
# Now let’s learn PATCH.

# PATCH means: Change part of existing data.

# After POST creates an item, the API returns its id.
#  We use that ID to tell the API which item to change.
# Get the ID from the item created with POST
object_id = created_item["id"]
# Information we want to change
change = {
    "name": "My new phone"
}
# Send the change
response = requests.patch(
    f"{url}/{object_id}",
    json=change
)
updated_item = response.json()
print(updated_item)
# Out:
# {'id': 'ff8081819f7e10ae019fa478aaad34be', 'name': 'My new phone', 'updatedAt': 1785170799761, 'data': {'color': 'black', 'price': 500}}

# %%
# DELETE means: Remove an existing item.
# We need the item’s id to tell the API which item to delete.
# Get the ID of the item created with POST
object_id = created_item["id"]

# Delete that item
response = requests.delete(f"{url}/{object_id}")

print(response.json())
# Out:
# {'message': 'Object with id = ff8081819f7e10ae019fa478aaad34be has been deleted.'}

# %% [markdown]
# ## Task 1:
# Let's start by exploring what's available in the API. Make a GET request to retrieve all objects from the restful-api.dev API.
# Store the response in a variable called response, then print:
#
# The status code
# The total number of objects (hint: use len() on response.json())

# %%
BASE_URL = 'https://api.restful-api.dev/objects'
response = requests.get(BASE_URL)
print(response.status_code)
print(len(response.json()))
# Out:
# 200
# 13

# %% [markdown]
# # Task 2:
# Now let's create something new! Use a POST request to add a new device to the API.
#
# Create a dictionary called new_device with:
#
# A "name" field with any device name you like (e.g., "iPhone 15 Pro")
# A "data" field containing a dictionary with at least two properties (e.g., color, capacity, price, etc.)
# Send the POST request and print:
#
# The status code (should be 200)
# The full response JSON (which will include the ID assigned to your new object)

# %%
new_device = {'name':"iPhone 15 Pro", 
              "data":{"color":"dark_blue", "capacity":"8G", "price":"200"}}
response = requests.post(BASE_URL, json= new_device)
print(response.json())
print(response.status_code)
# Out:
# {'id': 'ff8081819f7e10ae019fa478b22a34bf', 'name': 'iPhone 15 Pro', 'createdAt': 1785170801195, 'data': {'color': 'dark_blue', 'capacity': '8G', 'price': '200'}}
# 200

# %% [markdown]
# ## Task 3:
# Let's practice updating data! First, create a new device using POST (like in Task 2). Save the ID from the response. Then, use a PATCH request to update just ONE property of that device.
#
# Steps:
#
# * Create a new device and store the response
# * Extract the ID from the response: object_id = response.json()['id']
# * Create an update_data dictionary with just the field(s) you want to change
# * Send a PATCH request to update that specific object
# *Print the status code and the updated object

# %%
new_device = {
    "name": "Samsung Galaxy S24",
    "data": {
        "color": "Phantom Black",
        "price": 899.99,
        "storage": "256 GB"}}
response = requests.post(BASE_URL, json=new_device)
object_id = response.json()['id']
print(f"Created object with ID: {object_id}")
# Step 2: Update just one property
uapdate_dat = {'data':{'price': 799.99}}
response_update = requests.patch(f"{BASE_URL}/{object_id}", json=uapdate_dat)
print(response_update.status_code)
print("Updated object:")
print(response_update.json())
# Out:
# Created object with ID: ff8081819f7e10ae019fa478b44634c0
# 200
# Updated object:
# {'id': 'ff8081819f7e10ae019fa478b44634c0', 'name': 'Samsung Galaxy S24', 'updatedAt': 1785170802148, 'data': {'price': 799.99}}

# %% [markdown]
# ### FastAPI Fundamentals
# ## Create my own API?
# The main idea is:
#
# * requests.get() sends a request.
# * FastAPI receives the request and returns an answer.
# * Uvicorn keeps your API running.

# %%
# %pip install fastapi uvicorn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)

import fastapi
print(fastapi.__version__)
# Out:
# /home/susan/tripleten review/software_development_tools/.venv/bin/python
# 0.140.0

# %%
# Step 1: Create main.py
from fastapi import FastAPI # Imports the FastAPI tool.

app = FastAPI() # Creates your API application and names it app.
# Create an application object.

# Creates a GET endpoint.
# The / means the main or home address:
# A decorator that specifies that GET requests made to the application's main URL
# must be handled by this function
@app.get("/Strat Web")
def hello():
    return {"message": "Hello World"}

# Step3: Start the API :uvicorn main:app --reload
#Each part has a meaning:
#uvicorn → starts the server
#main → looks for main.py
#pp → looks for the variable named app
# --reload → restarts automatically when you change the code

# %% [markdown]
# ## Creating API Endpoints with PUT requests

# %%
app= FastAPI()
@ app.get('/')
def read_root():
    return{'Hello': 'FastAPI'}


# New PUT endpoint
# New PUT endpoint
@app.put('/user/{user_id}')
def update_user(user_id: int, name: str, age: int):
    return {
        "user_id": user_id,
        "name": name,
        "age": age,
        "message": f"User {user_id} has been updated"}

# %% [markdown]
#  Concept of modular code organization comes in. By splitting your code into multiple files, each with a specific purpose, you make your application easier to understand, maintain, and collaborate on.

# %%
# File 1: helpers.py (contains a function)
def greet_user(name):
    return f"Hello, {name}!"
# File 2: main.py (uses the function from File 1)
#from helpers import greet_user
result = greet_user("Alice")
print(result)
# Out:
# Hello, Alice!
